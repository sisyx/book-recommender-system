# %%
import pandas as pd

# %%
df = pd.read_csv("dataset/books.csv")

# %%
df.head()
# Out:
#    Unnamed: 0     id                                               name  \
# 0           0  41421  ""We Only Come Here to Struggle"": Stories fro...
# 1           1  24571                                    "A" Is For Asia
# 2           2  27640  "A" Is for Abductive : The Language of the Eme...
# 3           3    209                                   "A" Is for Zebra
# 4           4  44572  "Age Doesn't Matter Unless You're a Cheese": W...
#
#    rating_dist1  pages_number  rating_dist4  rating_dist_total  \
# 0             0           176             1                  7
# 1             0            32            18                 40
# 2             5           338            14                 49
# 3             1            32            22                 60
# 4             0           416            28                 66
#
#                     publisher  counts_of_review  publish_year language  \
# 0    Indiana University Press                 0          2000      NaN
# ...
